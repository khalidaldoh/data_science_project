# %%
# Importing libraries
import pandas as pd
import numpy as np

# %%
# Reading the excel to a dataframe
df = pd.read_excel("Group3_Dataset_of_Employee_Attrition.xlsx")

# %%
# Exploring the first 5 rows
df.head()
# Out:
#         ID Attrition Gender         Age  Maritalstatus  Academic_degree   \
# 0       11       Yes  Female   31 to 40        Married          Master's
# 1       12        No  Female  21 to 30          Single          Master's
# 2       13        No  Female  21 to 30          Single        Bachelor's
# 3       14        No  Female  21 to 30          Single        Bachelor's
# 4       15        No  Female  21 to 30          Single        Bachelor's
# ...    ...       ...     ...        ...            ...               ...
# 1186  1209        No  Female  21 to 30         Married        Bachelor's
# 1187  1210        No  Female  21 to 30         Married          Master's
# 1188  1211       Yes    Male  21 to 30          Single          Master's
# 1189  1212       Yes  Female   31 to 40        Married          Master's
# 1190  1213        No  Female  21 to 30          Single          Master's
#
#          Years_Experience Years_experience_lastorganization            Sector  \
# ...

# %%
# Exploring general dataset information
print("Dataset information:")
print(df.info())
# Out:
# Dataset information:
# <class 'pandas.DataFrame'>
# RangeIndex: 1191 entries, 0 to 1190
# Data columns (total 35 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   ID                                          1191 non-null   int64
#  1   Attrition                                   1191 non-null   str
#  2   Gender                                      1191 non-null   str
#  3   Age                                         1191 non-null   str
#  4    Maritalstatus                              1191 non-null   str
#  5    Academic_degree                            1191 non-null   str
#  6   Years_Experience                            1191 non-null   str
#  7   Years_experience_lastorganization           1191 non-null   str
#  8   Sector                                      1191 non-null   str
#  9   Department                                  1191 non-null   str
# ...

# %%
# Dropping the ID column because it does not have any useful information
df = df.drop(columns=["ID"])

# %%
# Normalizing the column names
df.columns = df.columns.str.strip().str.replace(" ","_")

# %%
# First 5 rows
df.head()
# Out:
#   Attrition  Gender        Age Maritalstatus Academic_degree  \
# 0       Yes  Female   31 to 40       Married        Master's
# 1        No  Female  21 to 30         Single        Master's
# 2        No  Female  21 to 30         Single      Bachelor's
# 3        No  Female  21 to 30         Single      Bachelor's
# 4        No  Female  21 to 30         Single      Bachelor's
#
#      Years_Experience Years_experience_lastorganization            Sector  \
# 0   Less than 5 years                 Less than 5 years    Medical sector
# 1   Less than 5 years                 Less than 5 years    Medical sector
# 2   Less than 5 years                 Less than 5 years  Education sector
# 3   Less than 5 years                 Less than 5 years  Education sector
# 4   Less than 5 years                 Less than 5 years  Education sector
#
#    Department    JobTitle  ... Job_Engagement  Distance_to_work  \
# 0  Accounting  Accountant  ...         Medium            Medium
# ...

# %%
# Exploring Statistical information of all columns values
print("Statistical description:")
df.describe()
# Out:
# Statistical description:
#         Allowances
# count  1191.000000
# mean      1.222502
# std       1.187483
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       2.000000
# max       4.000000

# %%
# Exploring missing values
print("Missing values:")
print(df.isnull().sum())
# Out:
# Missing values:
# Attrition                                     0
# Gender                                        0
# Age                                           0
#  Maritalstatus                                0
#  Academic_degree                              0
# Years_Experience                              0
# Years_experience_lastorganization             0
# Sector                                        0
# Department                                    0
# JobTitle                                      0
# MonthlySalary                                 0
# Allowances                                    0
# MedicalInsurance                              0
# Bonus                                         0
# OverTime                                      0
# Payment_Overtime                              0
# Rewards&Wages_Satisfaction                    0
# Get_ Deserved_Promotion                       0
# Training_programs_ During_last_three_years    0
# ...
